# %%
from pathlib import Path
from IPython.display import HTML, display

# Run this once before starting RISE slideshow.
# Loads slideshow style from a separate CSS file in this folder.
css_path = Path("slideshow-rise.css")

if css_path.exists():
    css = css_path.read_text(encoding="utf-8")
    display(HTML(f"<style id='rise-font-zoom'>\n{css}\n</style>"))
    print(f"Ready to start slideshow.")
    #print(f"Loaded slideshow style from {css_path.resolve()}")
else:
    print("slideshow-rise.css not found in notebook folder.")
    print("Create the file and run this cell again.")
# Out:
# <style id='rise-font-zoom'>
# /* RISE slideshow font sizing for JupyterLab */
# /*
#    Quick tuning (change ONLY these values):
#    - Normal full-screen projector: --slide-scale: 1.00
#    - Slightly larger:            --slide-scale: 1.08
#    - Large room:                 --slide-scale: 1.15
# */
#
# :root {
#   --slide-scale: 1.10;
#   --body-size: 1.05em;
#   --code-size: 1.02em;
#   --body-line: 1.30;
#   --code-line: 1.28;
#   --code-panel-max-h: 34vh;
#   --output-panel-max-h: 30vh;
# }
#
# /* Base slide scaling */
# .reveal .slides section {
#   font-size: calc(1em * var(--slide-scale)) !important;
#   overflow-y: auto !important;
#   overflow-x: hidden !important;
# }
#
# /* Markdown-rendered text */
# .reveal .jp-RenderedHTMLCommon,
# .reveal .jp-RenderedHTMLCommon p,
# .reveal .jp-RenderedHTMLCommon li,
# .reveal .jp-RenderedText,
# .reveal .jp-MarkdownCell {
#   font-size: var(--body-size) !important;
#   line-height: var(--body-line) !important;
# }
#
# /* Headings */
# ...

# %% [markdown]
# # CS 119: Python Programming
# ## Data Structures: A. Lists and Dictionaries

# %% [markdown]
# ## Today's roadmap
# 1. Lists
#    - Ordered by position
#    - Accessed by index
#    - Mutable
#      - Add items
#      - Change items
#      - Remove items
#    - Useful for ordered collections
#
# 2. Dictionaries
#    - Store key-value pairs
#    - Accessed by key
#    - Mutable
#      - Add key-value pairs
#      - Change values
#      - Remove key-value pairs
#    - Useful for labeled information

# %% [markdown]
# ## 1. Lists
# - `list`: an ordered, changeable collection of items.
# - Lists use index positions starting at `0`.
#
# Use a list when:
# - order matters (e.g. course sequence, checklist)
# - you need add/remove/update by position
#
# But first, ***why?***

# %%
# Why list? Compare 5 separate variables vs 1 list variable

# Option A: five separate variables (harder to manage as data grows)
course1 = 'CS 003A'
course2 = 'CS 003B'
course3 = 'CS 008'
course4 = 'CS 020'
course5 = 'CS 021'

print('Using separate variables:')
print(course1, course2, course3, course4, course5)

# Option B: one list variable (easier to loop, count, and update)
my_course_plan = ['CS 003A', 'CS 003B', 'CS 008', 'CS 020', 'CS 021']

print('\nUsing one list variable:')
print(my_course_plan)
print('First course (index 0):', my_course_plan[0])
print('Total courses:', len(my_course_plan))
print('Last course:', my_course_plan[-1])
# Out:
# Using separate variables:
# CS 003A CS 003B CS 008 CS 020 CS 021
#
# Using one list variable:
# ['CS 003A', 'CS 003B', 'CS 008', 'CS 020', 'CS 021']
# First course (index 0): CS 003A
# Total courses: 5
# Last course: CS 021

# %% [markdown]
# ## Lists: organization, access and applications
# - Ordered by position: a list keeps sequence (`0, 1, 2, ...`).
# - Accessed by index: use `my_list[0]`, `my_list[-1]`.
# - Mutable: we can add, change, and remove items.
# - Useful for ordered collections: course plans, checklists, schedules.
#
# The next few code cells show all of these in order.

# %%
# List operations: access, length, membership, add, change, remove-by-value, remove-by-position
print('Start:' , my_course_plan)

# length of list
print('Total courses:', len(my_course_plan))
# index starts at 0
print("First course:", my_course_plan[0])
print("Third course:", my_course_plan[2])
# negative index counts from the end of the list
print("Last course:", my_course_plan[-1])
print("Second-to-last course:", my_course_plan[-2])
print("Last course using positive index:", my_course_plan[len(my_course_plan) + (-1)]) # equals to len(my_course_plan) - 1
print('Total courses:', len(my_course_plan))

# %%
# Use `in` to check membership
print("'CS 008' in plan?", 'CS 008' in my_course_plan)

# Add one new course at the end
my_course_plan.append('CS 025')

# Change one item by index
my_course_plan[1] = 'CS 007'

# Remove one course by value
my_course_plan.remove('CS 020')

# Remove one course by position (index)
removed_course = my_course_plan.pop(0)
print('Removed by position:', removed_course)

print('After all updates:', my_course_plan)

# %%
# Loop through list items
for i, course in enumerate(my_course_plan, start=1):
    print(f'{i}. {course}')

# %% [markdown]
# ## Guided Practice 1: Lists
# Goal: practice reading a list, deduplicating, and counting.
#
# Steps:
# 1. Read the data list.
# 2. Build a new list with unique items.
# 3. Print the final list and length.

# %% [markdown]
# Task: You have a list of assignment deadlines.
# 1. Remove duplicates while keeping first-seen order.
# 2. Print how many unique deadlines remain.
#
# Data: `deadlines = ['Mon', 'Wed', 'Mon', 'Fri', 'Wed']`

# %%
# Starter (students edit this cell)
deadlines = ['Mon', 'Wed', 'Mon', 'Fri', 'Wed']
unique_days = []

# TODO 1: Loop through each day
for day in deadlines:
    # TODO 2: Keep only first occurrence
    pass

# TODO 3: Print final results
print('Unique days:', unique_days)
print('Count:', len(unique_days))

# %%
# One possible solution
deadlines = ['Mon', 'Wed', 'Mon', 'Fri', 'Wed']
unique_days = []
for day in deadlines:
    if day not in unique_days:
        unique_days.append(day)
print(unique_days, len(unique_days))

# %% [markdown]
# ## 2. Dictionaries
# - Store key-value pairs
# - Accessed by key
# - Mutable: we can add, change, and remove key-value pairs
# - Useful for labeled information: data by category, profile fields, settings
#
# The next code cell gives some examples.

# %%
# Dictionary operations: add, change, remove
weekly_hours = { # look carefully: something is wrong here!
    'study': 8,
    'work': 20,
    'commute': 6,
}

# Access by key
print('Study hours:', weekly_hours['study'])

# Change existing value
weekly_hours['study'] = 10

# Add new key-value pair
weekly_hours['exercise'] = 3

# Remove key-value pair
removed = weekly_hours.pop('commute')
print('Removed commute hours:', removed)

# Loop through all key-value pairs
for area, hrs in weekly_hours.items():
    print(f'{area}: {hrs} hours')

# %% [markdown]
# ## Common Gotchas
# - List index starts at `0`, not `1`. Negative indices start at -1 (the last).
# - Dictionary keys are case-sensitive (`'Name'` is not `'name'`).
# - Accessing a missing dictionary key causes an error; use `dict.get(key, default)` when unsure.

# %% [markdown]
# ## Guided Practice 2: Dictionaries
# Goal: create, read, and print dictionary values.
#
# Steps:
# 1. Create a dictionary with the required keys.
# 2. Build one summary sentence from dictionary values.
# 3. Print the goals ***list***.

# %% [markdown]
# Task: Create a dictionary with keys:
# - name
# - major
# - units
# - goals (a list of strings)
#
# Then print one sentence summary from the dictionary values.

# %%
# Step 1: Create dictionary
profile = {
    'name': 'Matt',
    'major': 'CS',
    'units': 15,
    'goals': ['Pass CS 119', 'Build coding confidence'],
}

# Step 2: Build one summary sentence
summary = f"{profile['name']} ({profile['major']}) is taking {profile['units']} units."
print(summary)

# Step 3: Read a list stored inside dictionary
print('Goals:', profile['goals'])

# %% [markdown]
# ## Example Combo: Weekly task completion
# Combine a list of tasks with a dictionary of completion counts.

# %%
# note list of tasks with duplicates
tasks = ['reading', 'coding practice', 'reading', 'quiz prep', 'coding practice', 'office hours', 'ask questions']
completed = {}

for task in tasks:
    completed[task] = completed.get(task, 0) + 1 # note the use of get() to handle missing keys

print('Task list:', tasks)
print('Completion counts:', completed)

# %%
for task, count in completed.items():
    print(f'{task}: {count}')

most_repeated = max(completed, key=completed.get)
print('Most repeated task:', most_repeated)

# %% [markdown]
# ## Takeaways today
# - `list` = ordered items by position (index starts at 0).
# - `dictionary` = key:value pairs by name.
# - Use `len(...)` to count items.
# - Use `.append(...)` to add to a list.
# - Use `dict.get(key, default)` when a key might be missing.

# %% [markdown]
# ## Lab assignment references
# - Lab 1: [labs/Lab_01_List_Warmup.md](labs/Lab_01_List_Warmup.md)
# - Lab 2: [labs/Lab_02_Dict_Tracker.md](labs/Lab_02_Dict_Tracker.md)
# - Lab 3: [labs/Lab_03_Integrated_Project.md](labs/Lab_03_Integrated_Project.md)
#
# These labs extend today's examples and can be done in class or homework.

# %% [markdown]
# ## Next class
# - Today: list and dictionary basics.
# - Next: writing reusable functions to process lists and dictionaries, tuples
#
# ## How to keep practicing
# 1. Re-run today's practice cells with your own data.
# 2. Complete the lab files linked above.
# 3. Explain each line of one solution out loud.

# %% [markdown]
# ## Want to learn more?
# Use these beginner-friendly references:
#
# - Lists
#   - Beginner: https://www.w3schools.com/python/python_lists.asp
#   - Official tutorial: https://docs.python.org/3/tutorial/datastructures.html#more-on-lists
#   - (Anecdotal) Why indexing starts at 0: https://medium.com/@jackpritomsoren/why-array-index-starts-from-0-the-real-reason-behind-the-scenes-5742efa0845c
#
# - Dictionaries
#   - Beginner: https://www.w3schools.com/python/python_dictionaries.asp
#   - Official tutorial: https://docs.python.org/3/tutorial/datastructures.html#dictionaries
